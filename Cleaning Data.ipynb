# %% [markdown]
# **Cleaning Data** <br>
# Week 3| Project 3| Level-1

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("CAvideos.csv")
df
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40876  sGolxsMSGfQ      18.14.06
# 40877  8HNuRNi8t70      18.14.06
# 40878  GWlKEM3m2EE      18.14.06
# 40879  lbMKLzQ4cNQ      18.14.06
# 40880  POTgw38-m58      18.14.06
#
#                                                    title     channel_title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                               I Dare You: GOING BALD!?          nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# ...                                                  ...               ...
# ...

# %%
df['trending_date'] = pd.to_datetime(df['trending_date'], format='%y.%d.%m')
df['publish_time'] = pd.to_datetime(df['publish_time'])

# %%
df['publish_date'] = df['publish_time'].dt.date
df['publish_time_only'] = df['publish_time'].dt.time

# %%
df['description'].fillna('', inplace=True)

# %%
df['category_id'] = df['category_id'].astype(str)

# %%
df.drop(columns=['publish_time'], inplace=True)

# %%
columns_to_drop = ['video_id', 'thumbnail_link']
df_cleaned = df.drop(columns=columns_to_drop)

# %%
df_cleaned = df_cleaned.drop_duplicates()

# %%
df_cleaned['tags'] = df_cleaned['tags'].str.lower()

# %%
numeric_columns = ['views', 'likes', 'dislikes', 'comment_count']
Q1 = df_cleaned[numeric_columns].quantile(0.25)
Q3 = df_cleaned[numeric_columns].quantile(0.75)
IQR = Q3 - Q1

outliers = (df_cleaned[numeric_columns] < (Q1 - 1.5 * IQR)) | (df_cleaned[numeric_columns] > (Q3 + 1.5 * IQR))

# %%
df_cleaned = df_cleaned[~outliers.any(axis=1)]

# %%
df_cleaned.info()
df_cleaned.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32518 entries, 9 to 40880
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   trending_date           32518 non-null  datetime64[ns]
#  1   title                   32518 non-null  object
#  2   channel_title           32518 non-null  object
#  3   category_id             32518 non-null  object
#  4   tags                    32518 non-null  object
#  5   views                   32518 non-null  int64
#  6   likes                   32518 non-null  int64
#  7   dislikes                32518 non-null  int64
#  8   comment_count           32518 non-null  int64
#  9   comments_disabled       32518 non-null  bool
#  10  ratings_disabled        32518 non-null  bool
#  11  video_error_or_removed  32518 non-null  bool
#  12  description             32518 non-null  object
#  13  publish_date            32518 non-null  object
# ...
